# %%
import pandas as pd

# %%
df=pd.read_csv("spam.csv", encoding="iso-8859-1")

# %%
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
import neattext as nt

# %%
#pip install neattext

# %%
df.shape
# Out:
# (5572, 5)

# %%
df.drop(["Unnamed: 2","Unnamed: 3","Unnamed: 4"],axis=1,inplace=True)

# %%
df.columns=["class","text"]

# %%
df
# Out:
#      class                                               text
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham              Will Ì_ b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
alll=" ".join(df["text"]) #merge all rows in the text column

# %%
sent=nt.TextFrame(alll)

# %%
sent.describe()
# Out:
# Key      Value
# Length  : 451993
# vowels  : 123893
# consonants: 203282
# stopwords: 36082
# punctuations: 22903
# special_char: 23446
# tokens(whitespace): 86335
# tokens(words): 90106

# %%
sent.length
# Out:
# 451993

# %%
sent.head()
# Out:
# 'Go un'

# %%
sent.count_vowels()
# Out:
# {'a': 25248, 'e': 34934, 'i': 22439, 'o': 28962, 'u': 12310}

# %%
sent.count_stopwords()
# Out:
# {'go': 262,
#  'until': 27,
#  'only': 183,
#  'in': 855,
#  'there': 135,
#  'a': 1419,
#  'to': 2226,
#  'may': 43,
#  'say': 80,
#  'so': 423,
#  'already': 48,
#  'then': 205,
#  'i': 2208,
#  "don't": 134,
#  'he': 180,
#  'around': 53,
#  'here': 79,
#  'though': 16,
#  "it's": 96,
#  'been': 128,
#  'now': 247,
#  'and': 967,
#  'no': 257,
#  'some': 118,
#  'you': 1917,
#  'up': 262,
#  'for': 697,
#  'it': 465,
#  'even': 61,
#  'my': 751,
#  'is': 862,
#  'not': 404,
#  'with': 377,
#  'they': 124,
#  'me': 605,
#  'as': 176,
#  'per': 56,
#  'your': 676,
#  'has': 115,
#  'all': 259,
#  'have': 568,
#  'call': 557,
#  'had': 100,
#  'or': 414,
#  'the': 1317,
#  'on': 520,
#  'be': 375,
#  'about': 156,
#  'this': 312,
#  'enough': 22,
#  'six': 4,
#  'from': 277,
#  'won': 64,
#  'our': 142,
#  'take': 124,
#  'will': 374,
#  'at': 398,
#  'next': 60,
#  'how': 253,
#  'his': 57,
#  'make': 101,
#  'if': 378,
#  'its': 207,
#  'that': 468,
#  'first': 50,
#  'when': 282,
# ...

# %%
sent.count_consonants()
# Out:
# {'b': 5310,
#  'c': 8876,
#  'd': 11275,
#  'f': 5745,
#  'g': 8284,
#  'h': 14204,
#  'j': 935,
#  'k': 4533,
#  'l': 15757,
#  'm': 10573,
#  'n': 21738,
#  'p': 6811,
#  'q': 236,
#  'r': 17738,
#  's': 18898,
#  't': 27921,
#  'v': 3504,
#  'w': 8462,
#  'x': 1586,
#  'y': 10396,
#  'z': 500}

# %%
sent.readability()
# Out:
# {'automated readability': 6.9861830850031055,
#  'description': '12-13 years (Seventh Grade)'}

# %%
import nltk #Natural Language Toolkit

# %%
#nltk.download("gutenberg")

# %%
nltk.corpus.gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
seyhbir=nltk.corpus.gutenberg.raw("shakespeare-macbeth.txt")

# %%
seyhbir
# Out:
# "[The Tragedie of Macbeth by William Shakespeare 1603]\n\n\nActus Primus. Scoena Prima.\n\nThunder and Lightning. Enter three Witches.\n\n  1. When shall we three meet againe?\nIn Thunder, Lightning, or in Raine?\n  2. When the Hurley-burley's done,\nWhen the Battaile's lost, and wonne\n\n   3. That will be ere the set of Sunne\n\n   1. Where the place?\n  2. Vpon the Heath\n\n   3. There to meet with Macbeth\n\n   1. I come, Gray-Malkin\n\n   All. Padock calls anon: faire is foule, and foule is faire,\nHouer through the fogge and filthie ayre.\n\nExeunt.\n\n\nScena Secunda.\n\nAlarum within. Enter King Malcome, Donalbaine, Lenox, with\nattendants,\nmeeting a bleeding Captaine.\n\n  King. What bloody man is that? he can report,\nAs seemeth by his plight, of the Reuolt\nThe newest state\n\n   Mal. This is the Serieant,\nWho like a good and hardie Souldier fought\n'Gainst my Captiuitie: Haile braue friend;\nSay to the King, the knowledge of the Broyle,\nAs thou didst leaue it\n\n   Cap
# ...

# %%
seyh=nt.TextFrame(seyhbir)

# %%
seyh.describe()
# Out:
# Key      Value
# Length  : 100351
# vowels  : 29039
# consonants: 46278
# stopwords: 7895
# punctuations: 4789
# special_char: 4789
# tokens(whitespace): 17741
# tokens(words): 18353

# %%
seyh.readability()
# Out:
# {'automated readability': 13.40177050724963,
#  'description': '18-24 years (College student)'}

# %%
import seaborn as sns

# %%
df.sample()
# Out:
#      class                                               text
# 4261   ham  You'll never believe this but i have actually ...

# %%
sns.countplot(x=df["class"])
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
#inbalanced data set

# %%
df["class"].value_counts()
# Out:
# class
# ham     4825
# spam     747
# Name: count, dtype: int64

# %%
#from imblearn.over_sampling import SMOTE
#x,y=SMOTE().fit_resample(x,y)

# %%
df['text']=df['text'].str.lower()

df['text']=df['text'].str.replace('[^\w\s]','',regex=True)

df['text']=df['text'].str.replace('\d+','',regex=True)

df['text']=df['text'].str.replace('\n','',regex=True)

df['text']=df['text'].str.replace('\r','',regex=True)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\w'
# <>:5: SyntaxWarning: invalid escape sequence '\d'
# <>:3: SyntaxWarning: invalid escape sequence '\w'
# <>:5: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\omerf\AppData\Local\Temp\ipykernel_16872\1281244372.py:3: SyntaxWarning: invalid escape sequence '\w'
#   df['text']=df['text'].str.replace('[^\w\s]','',regex=True)
# C:\Users\omerf\AppData\Local\Temp\ipykernel_16872\1281244372.py:5: SyntaxWarning: invalid escape sequence '\d'
#   df['text']=df['text'].str.replace('\d+','',regex=True)

# %%
y=df["class"]
x=df["text"]

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %%
from sklearn.pipeline import Pipeline

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
clf=Pipeline([("tfidf",TfidfVectorizer()),("classfier",RandomForestClassifier())])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test,y_train,y_test=train_test_split(x,y,test_size=.25,random_state=42)

# %%
clf.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                 ('classfier', RandomForestClassifier())])

# %%
y_pred=clf.predict(x_test)

# %%
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9698492462311558

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[1202,    0],
#        [  42,  149]], dtype=int64)

# %%
from sklearn.svm import SVC

# %%
svm=Pipeline([("tfidf",TfidfVectorizer()),("classfier",SVC())])

# %%
svm.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()), ('classfier', SVC())])

# %%
y_pred=svm.predict(x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9763101220387652

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[1202,    0],
#        [  33,  158]], dtype=int64)

# %%
sns.heatmap(confusion_matrix(y_test,y_pred),annot=True)
# Out:
# <Axes: >

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.97      1.00      0.99      1202
#         spam       1.00      0.83      0.91       191
#
#     accuracy                           0.98      1393
#    macro avg       0.99      0.91      0.95      1393
# weighted avg       0.98      0.98      0.98      1393

# %%
test1=["Hello, you are learning Natural Language Processing"]
test2=["Congr<tulations, you won a lottary ticket. To claim call 1-800-899-9999"]

# %%
clf.predict(test1)
# Out:
# array(['ham'], dtype=object)

# %%
clf.predict(test2)
# Out:
# array(['spam'], dtype=object)

# %%
svm.predict(test1)
# Out:
# array(['ham'], dtype=object)

# %%
svm.predict(test2)
# Out:
# array(['spam'], dtype=object)

# %%
df["text"][250]
# Out:
# 'ranjith cal drpd deeraj and deepak min hold'

# %%
svm.predict([df["text"][250]])
# Out:
# array(['ham'], dtype=object)

# %%
df["text"][2]
# Out:
# 'free entry in  a wkly comp to win fa cup final tkts st may  text fa to  to receive entry questionstd txt ratetcs apply overs'

# %%
svm.predict([df["text"][2]])
# Out:
# array(['spam'], dtype=object)

# %%
ham=df[df["class"]=="ham"]
spam=df[df["class"]=="spam"]

# %%
#Data augmentation
#Synthetic Data

# %%
#pip install wordcloud

# %%
from wordcloud import WordCloud
from wordcloud import STOPWORDS
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
def wc(data,color):
    plt.figure(figsize=(10,10))
    wc=WordCloud(background_color=color, stopwords=STOPWORDS)
    wc.generate(" ".join(ham["text"]))
    plt.imshow(wc)
    plt.axis("off")

# %%
wc(ham["text"],"white")

# %%
wc(spam["text"],"red")

# %%
#ham=ham.sample(spam.shape[0])
spam=spam.sample(ham.shape[0], replace=True)

# %%
ham.shape,spam.shape
# Out:
# ((4825, 2), (4825, 2))

# %%
data=pd.concat([ham,spam],ignore_index=True)

# %%
data.shape
# Out:
# (9650, 2)

# %%
sns.countplot(x=data["class"],hue=data["class"])
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
x_train, x_test,y_train,y_test=train_test_split(data["text"],data["class"],test_size=.20,random_state=42)

# %%
clf=Pipeline([("tfidf",TfidfVectorizer()),("classfier",RandomForestClassifier())])

# %%
clf.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                 ('classfier', RandomForestClassifier())])

# %%
y_pred=clf.predict(x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
#Sentiment Analysis

# %%
#pip install textblob

# %%
from textblob import TextBlob

# %%
text="I hate you"

# %%
blob=TextBlob(text)

# %%
blob.sentiment
# Out:
# Sentiment(polarity=-0.8, subjectivity=0.9)

# %%
#pip install spacy

# %%
#!python -m spacy download en_core_web_md

# %%
import spacy

# %%
# tokenization
#Named entitity recognitation
#Topic Modelling
#PoS tagging
#Lemma Stemma

# %%
nlp=spacy.load(name="en_core_web_md")

# %%
s1='''If the time has come to set sail,
A ship departs this port for the unknown.

It departs in silence, as if it had no passengers;
Neither a handkerchief nor an arm is waved in its departure.'''

# %%
doc1=nlp(s1)

# %%
[x for x in doc1]
# Out:
# [If,
#  the,
#  time,
#  has,
#  come,
#  to,
#  set,
#  sail,
#  ,,
#  ,
#  A,
#  ship,
#  departs,
#  this,
#  port,
#  for,
#  the,
#  unknown,
#  .,
#
#  ,
#  It,
#  departs,
#  in,
#  silence,
#  ,,
#  as,
#  if,
#  it,
#  had,
#  no,
#  passengers,
#  ;,
#  ,
#  Neither,
#  a,
#  handkerchief,
#  nor,
#  an,
#  arm,
#  is,
#  waved,
#  in,
#  its,
#  departure,
#  .]

# %%
s1=[x for x in doc1]

# %%
[x.lemma_ for x in s1]
# Out:
# ['if',
#  'the',
#  'time',
#  'have',
#  'come',
#  'to',
#  'set',
#  'sail',
#  ',',
#  '\n',
#  'a',
#  'ship',
#  'depart',
#  'this',
#  'port',
#  'for',
#  'the',
#  'unknown',
#  '.',
#  '\n\n',
#  'it',
#  'depart',
#  'in',
#  'silence',
#  ',',
#  'as',
#  'if',
#  'it',
#  'have',
#  'no',
#  'passenger',
#  ';',
#  '\n',
#  'neither',
#  'a',
#  'handkerchief',
#  'nor',
#  'an',
#  'arm',
#  'be',
#  'wave',
#  'in',
#  'its',
#  'departure',
#  '.']

# %%
doc=nlp("Apple is looking at buying U.K. startup for $1 billion")

# %%
for token in doc:
    print(token.text, token.lemma_, token.pos_, token.tag_)
# Out:
# Apple Apple PROPN NNP
# is be AUX VBZ
# looking look VERB VBG
# at at ADP IN
# buying buy VERB VBG
# U.K. U.K. PROPN NNP
# startup startup NOUN NN
# for for ADP IN
# $ $ SYM $
# 1 1 NUM CD
# billion billion NUM CD

# %%
from spacy import displacy

# %%
displacy.render(doc,style="dep")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="c987a4bb72754a8ba1e26fb4a91f3aef-0" class="displacy" width="1975" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Apple</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
# ...

# %%
#Named entity recognition NER

# %%
text="""Zafer Acar loves NLP and artificial intelligence, Python is a great programming language.
The Turkish Space Agency is the national space agency of Turkey, headquartered in Ankara.
It operates under the Department of Space which is tirectly overseen
by the President of Turkey and administrator of TUA is Serdar Hüseyin Yıldırım."""

# %%
doc=nlp(text)

# %%
displacy.render(doc,style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Zafer Acar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  loves
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NLP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and artificial intelligence,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Python
# ...
