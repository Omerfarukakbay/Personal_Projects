# %%
#We will built a racing bar video about Covid-19

# %%
#pip install ffmpeg
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for ffmpeg: filename=ffmpeg-1.4-py3-none-any.whl size=6082 sha256=749b44253b30cd8d82bfb78f344b3474de03c5f4dd2aba8e6f55ea2b833731ba
#   Stored in directory: /root/.cache/pip/wheels/8e/7a/69/cd6aeb83b126a7f04cbe7c9d929028dc52a6e7d525ff56003a
# Successfully built ffmpeg
# ...

# %%
#pip install bar_chart_race
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 kB 8.0 MB/s eta 0:00:00
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv("corona_dat.csv")

# %%
df.sample()
# Out:
#          date  Afghanistan  Albania  Algeria  Andorra  Angola  \
# 57  3/19/2020            0        5       35       14       0
#
#     Antigua and Barbuda  Argentina  Armenia  Australia  ...  Uruguay    US  \
# 57                    0         19       31        116  ...       15  6074
#
#     Uzbekistan  Venezuela  Vietnam  West Bank and Gaza  Western Sahara  Yemen  \
# 57           8          6       10                   3               0      0
#
#     Zambia  Zimbabwe
# 57       0         0
#
# [1 rows x 188 columns]

# %%
df2=df[["date","China","Italy","Brazil","US","Turkey"]]

# %%
df2.head()
# Out:
#         date  China  Italy  Brazil  US  Turkey
# 0  1/22/2020    593      0       0   1       0
# 1  1/23/2020     98      0       0   0       0
# 2  1/24/2020    291      0       0   1       0
# 3  1/25/2020    505      0       0   0       0
# 4  1/26/2020    693      0       0   3       0

# %%
df2.set_index("date",inplace=True)

# %%
summ=df2.cumsum(axis=0)

# %%
summ.head()
# Out:
#            China  Italy  Brazil  US  Turkey
# date
# 1/22/2020    593      0       0   1       0
# 1/23/2020    691      0       0   1       0
# 1/24/2020    982      0       0   2       0
# 1/25/2020   1487      0       0   2       0
# 1/26/2020   2180      0       0   5       0

# %%
import bar_chart_race as bcr

# %%
bcr.bar_chart_race(df=summ,filename="covid19.mp4",figsize=(10,8),title="Ömer")
# Out:
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:889: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_values.iloc[:, 0] = df_values.iloc[:, 0].fillna(method='ffill')
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:286: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(self.df_values.columns)
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))
